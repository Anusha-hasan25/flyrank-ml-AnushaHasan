# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Anusha-hasan25/flyrank-ml-AnushaHasan/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Lane 2: Refresh / Content Opportunity Scoring. I'm choosing this because it has a clear decision behind it (which pages does a reviewer look at first), it's directly supported by the starter dataset, and it lets me build on real signals (staleness, CTR-by-position, visibility) rather than an abstract or under-supported direction like AI-referral, which the lane guide flags as too sparse for reliable modeling this early.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Question: Which pages should be reviewed first for refresh, given limited reviewer capacity?
# Decision it improves: where a content team spends its limited review time.
# Action someone takes: a reviewer opens the top-ranked pages and decides to refresh, expand, or leave them.
# Cost of a wrong call: if the model over-flags a page that isn't actually a problem, reviewer time is wasted on a page that didn't need attention. If it under-flags a genuinely declining page, a real opportunity gets missed and the page keeps losing visibility unnoticed. Since this is decision-support, not automated action, the immediate cost of an error is wasted attention — not a broken page — which keeps the risk relatively low while still being worth minimizing.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/Anusha-hasan25/flyrank-ml-AnushaHasan"
REPO_DIR = "flyrank-ml-AnushaHasan"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("../..")  # from work/notebooks/ back to repo root

print("Working dir:", os.getcwd())
print("Data file exists:", os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# Working dir: /content/flyrank-ml-AnushaHasan
# Data file exists: True

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# I can say this is decision-support: a ranked list that helps a reviewer prioritize limited time, based on observed signals. I cannot claim this predicts Google's algorithm, guarantees a refresh will cause recovery, or proves causation of any kind — only correlation and pattern in observed data. Any output should use words like "observed," "directional," and "decision-support," never "proven" or "will recover."

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
